# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (4, 14)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 4 to 14:
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
# the lime is her least liked fruit , but the banana is my least liked .
# he saw a old yellow truck .
# india is rainy during june , and it is sometimes warm in november .
# that cat was my most loved animal .
#
# French sentences 4 to 14:
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .
# la chaux est son moins aimé des fruits , mais la banane est mon moins aimé.
# il a vu un vieux camion jaune .
# inde est pluvieux en juin , et il est parfois chaud en novembre .
# ce chat était mon animal le plus aimé .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    # split source_text by line
    source_text = [line.split() for line in source_text.split('\n')]
    source_id_text = []
    
    # get ids
    for line in source_text:
        source_id_text.append([source_vocab_to_int[word] for word in line])
    
    # split target_text by line    
    target_text = [line.split() for line in target_text.split('\n')]
    target_id_text = []
    
    # append 'EOS' and get ids
    for line in target_text:
        line.extend(['<EOS>'])
        target_id_text.append([target_vocab_to_int[word] for word in line])
        
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    inputs = tf.placeholder(tf.int32,shape=[None,None],name='input')
    targets = tf.placeholder(tf.int32,shape=[None,None],name='targets')
    learning_rate = tf.placeholder(tf.float32,shape=[],name='learning_rate')
    keep_prob = tf.placeholder(tf.float32,shape=[],name='keep_prob')
    target_sequence_length = tf.placeholder(tf.int32,[None,],name='target_sequence_length')
    max_target_length = tf.reduce_max(target_sequence_length,name = "max_target_len")
    source_sequence_length = tf.placeholder(tf.int32,[None,],name='source_sequence_length')
    
    return (inputs,targets,learning_rate,keep_prob,target_sequence_length,max_target_length,source_sequence_length)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0,0], [batch_size, -1], [1,1])
    output = tf.concat([tf.fill([batch_size,1], target_vocab_to_int['<GO>']), ending], 1)
    return output

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    
    inputs = tf.contrib.layers.embed_sequence(rnn_inputs,source_vocab_size,encoding_embedding_size)

    def make_cell(rnn_size):
        encoded_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                          initializer = tf.random_uniform_initializer(-0.1,0.1, seed = 2))
        return encoded_cell
    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    output,state = tf.nn.dynamic_rnn(enc_cell,inputs,sequence_length=source_sequence_length,
                                    dtype=tf.float32)
    return output, state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs = dec_embed_input, 
                                                       sequence_length = target_sequence_length)
    training_decoder = tf.contrib.seq2seq.BasicDecoder(cell = dec_cell,
                                                helper = training_helper,
                                                initial_state = encoder_state,
                                                output_layer = output_layer)
    final_outputs,dummy_variable =  tf.contrib.seq2seq.dynamic_decode(decoder = training_decoder,
                                                             impute_finished = True,
                                                             maximum_iterations = max_summary_length)                                                                                            
    return final_outputs



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')

    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                                start_tokens,
                                                                end_of_sequence_id)
    
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                        inference_helper,
                                                        encoder_state,
                                                        output_layer)
    
    inference_decoder_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                            impute_finished=True,
                                                            maximum_iterations=max_target_sequence_length)[0]
    return inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    lstm_cells = [] 
    start_sequence_id = target_vocab_to_int['<GO>']
    end_sequence_id = target_vocab_to_int['<EOS>']
    
    decode_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size], -1, 1))
    decode_embed_input = tf.nn.embedding_lookup(decode_embeddings, dec_input)
    
    for _ in range(num_layers):
        lstm_cell = tf.contrib.rnn.BasicLSTMCell(rnn_size)
        lstm_cells.append(lstm_cell)
        
    stacked_lstm_cells = tf.contrib.rnn.MultiRNNCell(lstm_cells)
    dec_cell = tf.contrib.rnn.DropoutWrapper(stacked_lstm_cells, keep_prob)
    output_layer = Dense(target_vocab_size, 
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))

    with tf.variable_scope("decode") as decoding_scope:
        training_logits = decoding_layer_train(encoder_state, 
                                                dec_cell,
                                                decode_embed_input,
                                                target_sequence_length,
                                                max_target_sequence_length,
                                                output_layer,
                                                keep_prob)
        decoding_scope.reuse_variables()
        inference_logits = decoding_layer_infer(encoder_state,
                                                dec_cell,
                                                decode_embeddings,
                                                start_sequence_id,
                                                end_sequence_id,
                                                max_target_sequence_length,
                                                target_vocab_size,
                                                output_layer,
                                                batch_size,
                                                keep_prob)

    
    
    
    return training_logits, inference_logits



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    encoder_output, encoder_state = encoding_layer(input_data,
                                                  rnn_size,
                                                  num_layers,
                                                  keep_prob,
                                                  source_sequence_length,
                                                  source_vocab_size,
                                                  enc_embedding_size)
    decode_input = process_decoder_input(target_data,
                                    target_vocab_to_int,
                                    batch_size)
    training_logits, inference_logits = decoding_layer(decode_input,
                            encoder_state,
                            target_sequence_length,
                            max_target_sentence_length,
                            rnn_size,
                            num_layers,
                            target_vocab_to_int,
                            target_vocab_size,
                            batch_size,
                            keep_prob,
                            dec_embedding_size)
    
    
    return training_logits, inference_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 8
# Batch Size
batch_size = 256
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 128
decoding_embedding_size = 128
# Learning Rate
learning_rate = .001
# Dropout Keep Probability
keep_probability = .7
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/538 - Train Accuracy: 0.2590, Validation Accuracy: 0.3464, Loss: 4.3255
# Epoch   0 Batch   20/538 - Train Accuracy: 0.3125, Validation Accuracy: 0.3555, Loss: 3.2793
# Epoch   0 Batch   30/538 - Train Accuracy: 0.2969, Validation Accuracy: 0.3640, Loss: 3.0854
# Epoch   0 Batch   40/538 - Train Accuracy: 0.4066, Validation Accuracy: 0.4128, Loss: 2.6421
# Epoch   0 Batch   50/538 - Train Accuracy: 0.3736, Validation Accuracy: 0.4327, Loss: 2.7129
# Epoch   0 Batch   60/538 - Train Accuracy: 0.3854, Validation Accuracy: 0.4466, Loss: 2.6066
# Epoch   0 Batch   70/538 - Train Accuracy: 0.4252, Validation Accuracy: 0.4634, Loss: 2.3720
# Epoch   0 Batch   80/538 - Train Accuracy: 0.3863, Validation Accuracy: 0.4558, Loss: 2.3654
# Epoch   0 Batch   90/538 - Train Accuracy: 0.4018, Validation Accuracy: 0.4396, Loss: 2.1449
# Epoch   0 Batch  100/538 - Train Accuracy: 0.3879, Validation Accuracy: 0.4457, Loss: 2.0699
# Epoch   0 Batch  110/538 - Train Accuracy: 0.3777, Validation Accuracy: 0.4403, Loss: 1.9979
# Epoch   0 Batch  120/538 - Train Accuracy: 0.3463, Validation Accuracy: 0.4199, Loss: 1.8466
# Epoch   0 Batch  130/538 - Train Accuracy: 0.3531, Validation Accuracy: 0.4130, Loss: 1.6822
# Epoch   0 Batch  140/538 - Train Accuracy: 0.3514, Validation Accuracy: 0.4190, Loss: 1.6878
# Epoch   0 Batch  150/538 - Train Accuracy: 0.3568, Validation Accuracy: 0.4260, Loss: 1.5451
# Epoch   0 Batch  160/538 - Train Accuracy: 0.3852, Validation Accuracy: 0.4357, Loss: 1.4162
# Epoch   0 Batch  170/538 - Train Accuracy: 0.4109, Validation Accuracy: 0.4489, Loss: 1.3615
# Epoch   0 Batch  180/538 - Train Accuracy: 0.4448, Validation Accuracy: 0.4600, Loss: 1.3111
# Epoch   0 Batch  190/538 - Train Accuracy: 0.4230, Validation Accuracy: 0.4529, Loss: 1.2981
# Epoch   0 Batch  200/538 - Train Accuracy: 0.4178, Validation Accuracy: 0.4739, Loss: 1.2427
# Epoch   0 Batch  210/538 - Train Accuracy: 0.4330, Validation Accuracy: 0.4792, Loss: 1.1655
# Epoch   0 Batch  220/538 - Train Accuracy: 0.4291, Validation Accuracy: 0.4707, Loss: 1.1250
# Epoch   0 Batch  230/538 - Train Accuracy: 0.4369, Validation Accuracy: 0.4821, Loss: 1.1270
# Epoch   0 Batch  240/538 - Train Accuracy: 0.4439, Validation Accuracy: 0.4931, Loss: 1.1030
# Epoch   0 Batch  250/538 - Train Accuracy: 0.4234, Validation Accuracy: 0.5069, Loss: 1.0333
# Epoch   0 Batch  260/538 - Train Accuracy: 0.4535, Validation Accuracy: 0.5075, Loss: 1.0103
# Epoch   0 Batch  270/538 - Train Accuracy: 0.4580, Validation Accuracy: 0.5206, Loss: 0.9998
# Epoch   0 Batch  280/538 - Train Accuracy: 0.5035, Validation Accuracy: 0.5162, Loss: 0.9208
# Epoch   0 Batch  290/538 - Train Accuracy: 0.4779, Validation Accuracy: 0.5408, Loss: 0.9519
# Epoch   0 Batch  300/538 - Train Accuracy: 0.5326, Validation Accuracy: 0.5424, Loss: 0.8824
# Epoch   0 Batch  310/538 - Train Accuracy: 0.5053, Validation Accuracy: 0.5462, Loss: 0.8918
# Epoch   0 Batch  320/538 - Train Accuracy: 0.5346, Validation Accuracy: 0.5538, Loss: 0.8640
# Epoch   0 Batch  330/538 - Train Accuracy: 0.5443, Validation Accuracy: 0.5648, Loss: 0.8255
# Epoch   0 Batch  340/538 - Train Accuracy: 0.5127, Validation Accuracy: 0.5653, Loss: 0.8686
# Epoch   0 Batch  350/538 - Train Accuracy: 0.5491, Validation Accuracy: 0.5666, Loss: 0.8317
# Epoch   0 Batch  360/538 - Train Accuracy: 0.5473, Validation Accuracy: 0.5730, Loss: 0.8335
# Epoch   0 Batch  370/538 - Train Accuracy: 0.5404, Validation Accuracy: 0.5758, Loss: 0.8216
# Epoch   0 Batch  380/538 - Train Accuracy: 0.5594, Validation Accuracy: 0.5874, Loss: 0.7782
# Epoch   0 Batch  390/538 - Train Accuracy: 0.5900, Validation Accuracy: 0.5861, Loss: 0.7465
# Epoch   0 Batch  400/538 - Train Accuracy: 0.5783, Validation Accuracy: 0.6055, Loss: 0.7464
# Epoch   0 Batch  410/538 - Train Accuracy: 0.5764, Validation Accuracy: 0.5890, Loss: 0.7589
# Epoch   0 Batch  420/538 - Train Accuracy: 0.5914, Validation Accuracy: 0.6065, Loss: 0.7264
# Epoch   0 Batch  430/538 - Train Accuracy: 0.5949, Validation Accuracy: 0.6007, Loss: 0.7257
# Epoch   0 Batch  440/538 - Train Accuracy: 0.5871, Validation Accuracy: 0.6129, Loss: 0.7490
# Epoch   0 Batch  450/538 - Train Accuracy: 0.6032, Validation Accuracy: 0.6083, Loss: 0.7086
# Epoch   0 Batch  460/538 - Train Accuracy: 0.5755, Validation Accuracy: 0.6081, Loss: 0.6793
# Epoch   0 Batch  470/538 - Train Accuracy: 0.6205, Validation Accuracy: 0.6278, Loss: 0.6726
# Epoch   0 Batch  480/538 - Train Accuracy: 0.6233, Validation Accuracy: 0.6197, Loss: 0.6563
# Epoch   0 Batch  490/538 - Train Accuracy: 0.6040, Validation Accuracy: 0.6225, Loss: 0.6556
# Epoch   0 Batch  500/538 - Train Accuracy: 0.6348, Validation Accuracy: 0.6223, Loss: 0.6093
# Epoch   0 Batch  510/538 - Train Accuracy: 0.6217, Validation Accuracy: 0.6317, Loss: 0.6376
# Epoch   0 Batch  520/538 - Train Accuracy: 0.6049, Validation Accuracy: 0.6227, Loss: 0.6637
# Epoch   0 Batch  530/538 - Train Accuracy: 0.6107, Validation Accuracy: 0.6298, Loss: 0.6694
# Epoch   1 Batch   10/538 - Train Accuracy: 0.5822, Validation Accuracy: 0.6310, Loss: 0.6507
# Epoch   1 Batch   20/538 - Train Accuracy: 0.6164, Validation Accuracy: 0.6360, Loss: 0.6160
# Epoch   1 Batch   30/538 - Train Accuracy: 0.6021, Validation Accuracy: 0.6284, Loss: 0.6431
# Epoch   1 Batch   40/538 - Train Accuracy: 0.6529, Validation Accuracy: 0.6234, Loss: 0.5446
# Epoch   1 Batch   50/538 - Train Accuracy: 0.6328, Validation Accuracy: 0.6415, Loss: 0.6089
# Epoch   1 Batch   60/538 - Train Accuracy: 0.6266, Validation Accuracy: 0.6465, Loss: 0.5916
# Epoch   1 Batch   70/538 - Train Accuracy: 0.6287, Validation Accuracy: 0.6385, Loss: 0.5675
# Epoch   1 Batch   80/538 - Train Accuracy: 0.6193, Validation Accuracy: 0.6481, Loss: 0.6110
# Epoch   1 Batch   90/538 - Train Accuracy: 0.6358, Validation Accuracy: 0.6463, Loss: 0.5775
# Epoch   1 Batch  100/538 - Train Accuracy: 0.6180, Validation Accuracy: 0.6463, Loss: 0.5608
# Epoch   1 Batch  110/538 - Train Accuracy: 0.6209, Validation Accuracy: 0.6428, Loss: 0.5719
# Epoch   1 Batch  120/538 - Train Accuracy: 0.6434, Validation Accuracy: 0.6506, Loss: 0.5355
# Epoch   1 Batch  130/538 - Train Accuracy: 0.6375, Validation Accuracy: 0.6562, Loss: 0.5310
# Epoch   1 Batch  140/538 - Train Accuracy: 0.6150, Validation Accuracy: 0.6525, Loss: 0.5776
# Epoch   1 Batch  150/538 - Train Accuracy: 0.6477, Validation Accuracy: 0.6605, Loss: 0.5440
# Epoch   1 Batch  160/538 - Train Accuracy: 0.6408, Validation Accuracy: 0.6685, Loss: 0.5155
# Epoch   1 Batch  170/538 - Train Accuracy: 0.6650, Validation Accuracy: 0.6618, Loss: 0.5206
# Epoch   1 Batch  180/538 - Train Accuracy: 0.6879, Validation Accuracy: 0.6589, Loss: 0.5048
# Epoch   1 Batch  190/538 - Train Accuracy: 0.6583, Validation Accuracy: 0.6712, Loss: 0.5252
# Epoch   1 Batch  200/538 - Train Accuracy: 0.6691, Validation Accuracy: 0.6639, Loss: 0.5009
# Epoch   1 Batch  210/538 - Train Accuracy: 0.6523, Validation Accuracy: 0.6747, Loss: 0.4953
# Epoch   1 Batch  220/538 - Train Accuracy: 0.6397, Validation Accuracy: 0.6621, Loss: 0.4805
# Epoch   1 Batch  230/538 - Train Accuracy: 0.6492, Validation Accuracy: 0.6721, Loss: 0.5006
# Epoch   1 Batch  240/538 - Train Accuracy: 0.6510, Validation Accuracy: 0.6781, Loss: 0.5009
# Epoch   1 Batch  250/538 - Train Accuracy: 0.6627, Validation Accuracy: 0.6761, Loss: 0.4772
# Epoch   1 Batch  260/538 - Train Accuracy: 0.6713, Validation Accuracy: 0.6737, Loss: 0.4693
# Epoch   1 Batch  270/538 - Train Accuracy: 0.6496, Validation Accuracy: 0.6737, Loss: 0.4759
# Epoch   1 Batch  280/538 - Train Accuracy: 0.7126, Validation Accuracy: 0.6763, Loss: 0.4355
# Epoch   1 Batch  290/538 - Train Accuracy: 0.6482, Validation Accuracy: 0.6783, Loss: 0.4471
# Epoch   1 Batch  300/538 - Train Accuracy: 0.6804, Validation Accuracy: 0.6850, Loss: 0.4466
# Epoch   1 Batch  310/538 - Train Accuracy: 0.7135, Validation Accuracy: 0.6884, Loss: 0.4510
# Epoch   1 Batch  320/538 - Train Accuracy: 0.7117, Validation Accuracy: 0.6964, Loss: 0.4271
# Epoch   1 Batch  330/538 - Train Accuracy: 0.7005, Validation Accuracy: 0.6774, Loss: 0.4092
# Epoch   1 Batch  340/538 - Train Accuracy: 0.6826, Validation Accuracy: 0.6834, Loss: 0.4366
# Epoch   1 Batch  350/538 - Train Accuracy: 0.7061, Validation Accuracy: 0.6999, Loss: 0.4221
# Epoch   1 Batch  360/538 - Train Accuracy: 0.7027, Validation Accuracy: 0.7060, Loss: 0.4238
# Epoch   1 Batch  370/538 - Train Accuracy: 0.7139, Validation Accuracy: 0.7067, Loss: 0.4184
# Epoch   1 Batch  380/538 - Train Accuracy: 0.7100, Validation Accuracy: 0.7106, Loss: 0.3947
# Epoch   1 Batch  390/538 - Train Accuracy: 0.7719, Validation Accuracy: 0.7140, Loss: 0.3830
# Epoch   1 Batch  400/538 - Train Accuracy: 0.7342, Validation Accuracy: 0.7017, Loss: 0.3785
# Epoch   1 Batch  410/538 - Train Accuracy: 0.7246, Validation Accuracy: 0.7021, Loss: 0.3950
# Epoch   1 Batch  420/538 - Train Accuracy: 0.7375, Validation Accuracy: 0.7132, Loss: 0.3765
# Epoch   1 Batch  430/538 - Train Accuracy: 0.7428, Validation Accuracy: 0.7188, Loss: 0.3676
# Epoch   1 Batch  440/538 - Train Accuracy: 0.7414, Validation Accuracy: 0.7477, Loss: 0.3841
# Epoch   1 Batch  450/538 - Train Accuracy: 0.7554, Validation Accuracy: 0.7244, Loss: 0.3705
# Epoch   1 Batch  460/538 - Train Accuracy: 0.7400, Validation Accuracy: 0.7363, Loss: 0.3478
# Epoch   1 Batch  470/538 - Train Accuracy: 0.7617, Validation Accuracy: 0.7338, Loss: 0.3330
# Epoch   1 Batch  480/538 - Train Accuracy: 0.7643, Validation Accuracy: 0.7401, Loss: 0.3324
# Epoch   1 Batch  490/538 - Train Accuracy: 0.7781, Validation Accuracy: 0.7362, Loss: 0.3244
# Epoch   1 Batch  500/538 - Train Accuracy: 0.8061, Validation Accuracy: 0.7346, Loss: 0.2947
# Epoch   1 Batch  510/538 - Train Accuracy: 0.7846, Validation Accuracy: 0.7377, Loss: 0.3100
# Epoch   1 Batch  520/538 - Train Accuracy: 0.7953, Validation Accuracy: 0.7559, Loss: 0.3249
# Epoch   1 Batch  530/538 - Train Accuracy: 0.7754, Validation Accuracy: 0.7638, Loss: 0.3346
# Epoch   2 Batch   10/538 - Train Accuracy: 0.7680, Validation Accuracy: 0.7520, Loss: 0.3182
# Epoch   2 Batch   20/538 - Train Accuracy: 0.7822, Validation Accuracy: 0.7594, Loss: 0.3068
# Epoch   2 Batch   30/538 - Train Accuracy: 0.7824, Validation Accuracy: 0.7681, Loss: 0.3159
# Epoch   2 Batch   40/538 - Train Accuracy: 0.7997, Validation Accuracy: 0.7841, Loss: 0.2634
# Epoch   2 Batch   50/538 - Train Accuracy: 0.8004, Validation Accuracy: 0.7880, Loss: 0.2886
# Epoch   2 Batch   60/538 - Train Accuracy: 0.8098, Validation Accuracy: 0.8018, Loss: 0.2871
# Epoch   2 Batch   70/538 - Train Accuracy: 0.8028, Validation Accuracy: 0.7798, Loss: 0.2700
# Epoch   2 Batch   80/538 - Train Accuracy: 0.8037, Validation Accuracy: 0.7843, Loss: 0.2896
# Epoch   2 Batch   90/538 - Train Accuracy: 0.7839, Validation Accuracy: 0.7809, Loss: 0.2846
# Epoch   2 Batch  100/538 - Train Accuracy: 0.8186, Validation Accuracy: 0.7935, Loss: 0.2622
# Epoch   2 Batch  110/538 - Train Accuracy: 0.8125, Validation Accuracy: 0.8093, Loss: 0.2675
# Epoch   2 Batch  120/538 - Train Accuracy: 0.8475, Validation Accuracy: 0.8136, Loss: 0.2443
# Epoch   2 Batch  130/538 - Train Accuracy: 0.8385, Validation Accuracy: 0.8082, Loss: 0.2379
# Epoch   2 Batch  140/538 - Train Accuracy: 0.8215, Validation Accuracy: 0.8111, Loss: 0.2679
# Epoch   2 Batch  150/538 - Train Accuracy: 0.8313, Validation Accuracy: 0.7958, Loss: 0.2452
# Epoch   2 Batch  160/538 - Train Accuracy: 0.8320, Validation Accuracy: 0.8162, Loss: 0.2340
# Epoch   2 Batch  170/538 - Train Accuracy: 0.8516, Validation Accuracy: 0.8205, Loss: 0.2382
# Epoch   2 Batch  180/538 - Train Accuracy: 0.8566, Validation Accuracy: 0.8130, Loss: 0.2342
# Epoch   2 Batch  190/538 - Train Accuracy: 0.8298, Validation Accuracy: 0.8342, Loss: 0.2496
# Epoch   2 Batch  200/538 - Train Accuracy: 0.8391, Validation Accuracy: 0.8292, Loss: 0.2213
# Epoch   2 Batch  210/538 - Train Accuracy: 0.8387, Validation Accuracy: 0.8377, Loss: 0.2218
# Epoch   2 Batch  220/538 - Train Accuracy: 0.8374, Validation Accuracy: 0.8256, Loss: 0.2178
# Epoch   2 Batch  230/538 - Train Accuracy: 0.8590, Validation Accuracy: 0.8326, Loss: 0.2223
# Epoch   2 Batch  240/538 - Train Accuracy: 0.8410, Validation Accuracy: 0.8358, Loss: 0.2205
# Epoch   2 Batch  250/538 - Train Accuracy: 0.8562, Validation Accuracy: 0.8265, Loss: 0.2036
# Epoch   2 Batch  260/538 - Train Accuracy: 0.8028, Validation Accuracy: 0.8294, Loss: 0.2107
# Epoch   2 Batch  270/538 - Train Accuracy: 0.8629, Validation Accuracy: 0.8386, Loss: 0.2012
# Epoch   2 Batch  280/538 - Train Accuracy: 0.8750, Validation Accuracy: 0.8274, Loss: 0.1817
# Epoch   2 Batch  290/538 - Train Accuracy: 0.8717, Validation Accuracy: 0.8361, Loss: 0.1871
# Epoch   2 Batch  300/538 - Train Accuracy: 0.8674, Validation Accuracy: 0.8493, Loss: 0.1925
# Epoch   2 Batch  310/538 - Train Accuracy: 0.8971, Validation Accuracy: 0.8327, Loss: 0.1859
# Epoch   2 Batch  320/538 - Train Accuracy: 0.8488, Validation Accuracy: 0.8335, Loss: 0.1725
# Epoch   2 Batch  330/538 - Train Accuracy: 0.8830, Validation Accuracy: 0.8340, Loss: 0.1710
# Epoch   2 Batch  340/538 - Train Accuracy: 0.8574, Validation Accuracy: 0.8530, Loss: 0.1810
# Epoch   2 Batch  350/538 - Train Accuracy: 0.8813, Validation Accuracy: 0.8468, Loss: 0.1792
# Epoch   2 Batch  360/538 - Train Accuracy: 0.8742, Validation Accuracy: 0.8542, Loss: 0.1727
# Epoch   2 Batch  370/538 - Train Accuracy: 0.8904, Validation Accuracy: 0.8535, Loss: 0.1767
# Epoch   2 Batch  380/538 - Train Accuracy: 0.8744, Validation Accuracy: 0.8491, Loss: 0.1551
# Epoch   2 Batch  390/538 - Train Accuracy: 0.8981, Validation Accuracy: 0.8736, Loss: 0.1471
# Epoch   2 Batch  400/538 - Train Accuracy: 0.8949, Validation Accuracy: 0.8638, Loss: 0.1583
# Epoch   2 Batch  410/538 - Train Accuracy: 0.8758, Validation Accuracy: 0.8519, Loss: 0.1674
# Epoch   2 Batch  420/538 - Train Accuracy: 0.8963, Validation Accuracy: 0.8690, Loss: 0.1492
# Epoch   2 Batch  430/538 - Train Accuracy: 0.8873, Validation Accuracy: 0.8640, Loss: 0.1452
# Epoch   2 Batch  440/538 - Train Accuracy: 0.8773, Validation Accuracy: 0.8780, Loss: 0.1608
# Epoch   2 Batch  450/538 - Train Accuracy: 0.8638, Validation Accuracy: 0.8773, Loss: 0.1592
# Epoch   2 Batch  460/538 - Train Accuracy: 0.8694, Validation Accuracy: 0.8789, Loss: 0.1454
# Epoch   2 Batch  470/538 - Train Accuracy: 0.8847, Validation Accuracy: 0.8730, Loss: 0.1339
# Epoch   2 Batch  480/538 - Train Accuracy: 0.9012, Validation Accuracy: 0.8681, Loss: 0.1338
# Epoch   2 Batch  490/538 - Train Accuracy: 0.9007, Validation Accuracy: 0.8754, Loss: 0.1323
# Epoch   2 Batch  500/538 - Train Accuracy: 0.9187, Validation Accuracy: 0.8871, Loss: 0.1132
# Epoch   2 Batch  510/538 - Train Accuracy: 0.9068, Validation Accuracy: 0.8814, Loss: 0.1219
# Epoch   2 Batch  520/538 - Train Accuracy: 0.8986, Validation Accuracy: 0.8803, Loss: 0.1363
# Epoch   2 Batch  530/538 - Train Accuracy: 0.8744, Validation Accuracy: 0.8842, Loss: 0.1399
# Epoch   3 Batch   10/538 - Train Accuracy: 0.8953, Validation Accuracy: 0.8615, Loss: 0.1304
# Epoch   3 Batch   20/538 - Train Accuracy: 0.9081, Validation Accuracy: 0.8846, Loss: 0.1244
# Epoch   3 Batch   30/538 - Train Accuracy: 0.8781, Validation Accuracy: 0.8686, Loss: 0.1310
# Epoch   3 Batch   40/538 - Train Accuracy: 0.8984, Validation Accuracy: 0.8899, Loss: 0.1027
# Epoch   3 Batch   50/538 - Train Accuracy: 0.8984, Validation Accuracy: 0.8800, Loss: 0.1096
# Epoch   3 Batch   60/538 - Train Accuracy: 0.9102, Validation Accuracy: 0.8983, Loss: 0.1141
# Epoch   3 Batch   70/538 - Train Accuracy: 0.9022, Validation Accuracy: 0.8894, Loss: 0.1093
# Epoch   3 Batch   80/538 - Train Accuracy: 0.8932, Validation Accuracy: 0.8929, Loss: 0.1199
# Epoch   3 Batch   90/538 - Train Accuracy: 0.9001, Validation Accuracy: 0.8986, Loss: 0.1178
# Epoch   3 Batch  100/538 - Train Accuracy: 0.9154, Validation Accuracy: 0.9045, Loss: 0.1005
# Epoch   3 Batch  110/538 - Train Accuracy: 0.9016, Validation Accuracy: 0.9013, Loss: 0.1057
# Epoch   3 Batch  120/538 - Train Accuracy: 0.9260, Validation Accuracy: 0.8993, Loss: 0.0893
# Epoch   3 Batch  130/538 - Train Accuracy: 0.9315, Validation Accuracy: 0.9013, Loss: 0.0917
# Epoch   3 Batch  140/538 - Train Accuracy: 0.9014, Validation Accuracy: 0.9009, Loss: 0.1126
# Epoch   3 Batch  150/538 - Train Accuracy: 0.9211, Validation Accuracy: 0.9130, Loss: 0.0929
# Epoch   3 Batch  160/538 - Train Accuracy: 0.8951, Validation Accuracy: 0.8938, Loss: 0.0956
# Epoch   3 Batch  170/538 - Train Accuracy: 0.9178, Validation Accuracy: 0.9112, Loss: 0.1004
# Epoch   3 Batch  180/538 - Train Accuracy: 0.9260, Validation Accuracy: 0.9009, Loss: 0.0930
# Epoch   3 Batch  190/538 - Train Accuracy: 0.8899, Validation Accuracy: 0.9141, Loss: 0.1151
# Epoch   3 Batch  200/538 - Train Accuracy: 0.9158, Validation Accuracy: 0.9084, Loss: 0.0843
# Epoch   3 Batch  210/538 - Train Accuracy: 0.8912, Validation Accuracy: 0.9118, Loss: 0.0896
# Epoch   3 Batch  220/538 - Train Accuracy: 0.9036, Validation Accuracy: 0.9094, Loss: 0.0937
# Epoch   3 Batch  230/538 - Train Accuracy: 0.9182, Validation Accuracy: 0.8890, Loss: 0.0910
# Epoch   3 Batch  240/538 - Train Accuracy: 0.9072, Validation Accuracy: 0.9091, Loss: 0.0932
# Epoch   3 Batch  250/538 - Train Accuracy: 0.9244, Validation Accuracy: 0.9153, Loss: 0.0801
# Epoch   3 Batch  260/538 - Train Accuracy: 0.8821, Validation Accuracy: 0.9094, Loss: 0.0930
# Epoch   3 Batch  270/538 - Train Accuracy: 0.9252, Validation Accuracy: 0.9055, Loss: 0.0783
# Epoch   3 Batch  280/538 - Train Accuracy: 0.9306, Validation Accuracy: 0.9070, Loss: 0.0737
# Epoch   3 Batch  290/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.8988, Loss: 0.0761
# Epoch   3 Batch  300/538 - Train Accuracy: 0.9150, Validation Accuracy: 0.9208, Loss: 0.0853
# Epoch   3 Batch  310/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9318, Loss: 0.0771
# Epoch   3 Batch  320/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9302, Loss: 0.0724
# Epoch   3 Batch  330/538 - Train Accuracy: 0.9336, Validation Accuracy: 0.9089, Loss: 0.0723
# Epoch   3 Batch  340/538 - Train Accuracy: 0.9107, Validation Accuracy: 0.9176, Loss: 0.0780
# Epoch   3 Batch  350/538 - Train Accuracy: 0.9299, Validation Accuracy: 0.9165, Loss: 0.0817
# Epoch   3 Batch  360/538 - Train Accuracy: 0.9268, Validation Accuracy: 0.9180, Loss: 0.0732
# Epoch   3 Batch  370/538 - Train Accuracy: 0.9322, Validation Accuracy: 0.9178, Loss: 0.0773
# Epoch   3 Batch  380/538 - Train Accuracy: 0.9232, Validation Accuracy: 0.9180, Loss: 0.0674
# Epoch   3 Batch  390/538 - Train Accuracy: 0.9286, Validation Accuracy: 0.9151, Loss: 0.0626
# Epoch   3 Batch  400/538 - Train Accuracy: 0.9323, Validation Accuracy: 0.9157, Loss: 0.0768
# Epoch   3 Batch  410/538 - Train Accuracy: 0.9207, Validation Accuracy: 0.9190, Loss: 0.0763
# Epoch   3 Batch  420/538 - Train Accuracy: 0.9357, Validation Accuracy: 0.9339, Loss: 0.0664
# Epoch   3 Batch  430/538 - Train Accuracy: 0.9207, Validation Accuracy: 0.9208, Loss: 0.0665
# Epoch   3 Batch  440/538 - Train Accuracy: 0.9256, Validation Accuracy: 0.9196, Loss: 0.0758
# Epoch   3 Batch  450/538 - Train Accuracy: 0.9126, Validation Accuracy: 0.9258, Loss: 0.0830
# Epoch   3 Batch  460/538 - Train Accuracy: 0.9211, Validation Accuracy: 0.9281, Loss: 0.0705
# Epoch   3 Batch  470/538 - Train Accuracy: 0.9433, Validation Accuracy: 0.9279, Loss: 0.0647
# Epoch   3 Batch  480/538 - Train Accuracy: 0.9392, Validation Accuracy: 0.9281, Loss: 0.0645
# Epoch   3 Batch  490/538 - Train Accuracy: 0.9433, Validation Accuracy: 0.9315, Loss: 0.0635
# Epoch   3 Batch  500/538 - Train Accuracy: 0.9435, Validation Accuracy: 0.9231, Loss: 0.0502
# Epoch   3 Batch  510/538 - Train Accuracy: 0.9366, Validation Accuracy: 0.9235, Loss: 0.0607
# Epoch   3 Batch  520/538 - Train Accuracy: 0.9242, Validation Accuracy: 0.9281, Loss: 0.0663
# Epoch   3 Batch  530/538 - Train Accuracy: 0.9035, Validation Accuracy: 0.9364, Loss: 0.0715
# Epoch   4 Batch   10/538 - Train Accuracy: 0.9285, Validation Accuracy: 0.9213, Loss: 0.0702
# Epoch   4 Batch   20/538 - Train Accuracy: 0.9297, Validation Accuracy: 0.9304, Loss: 0.0629
# Epoch   4 Batch   30/538 - Train Accuracy: 0.9258, Validation Accuracy: 0.9212, Loss: 0.0715
# Epoch   4 Batch   40/538 - Train Accuracy: 0.9379, Validation Accuracy: 0.9345, Loss: 0.0512
# Epoch   4 Batch   50/538 - Train Accuracy: 0.9342, Validation Accuracy: 0.9448, Loss: 0.0592
# Epoch   4 Batch   60/538 - Train Accuracy: 0.9330, Validation Accuracy: 0.9302, Loss: 0.0618
# Epoch   4 Batch   70/538 - Train Accuracy: 0.9304, Validation Accuracy: 0.9324, Loss: 0.0558
# Epoch   4 Batch   80/538 - Train Accuracy: 0.9301, Validation Accuracy: 0.9286, Loss: 0.0622
# Epoch   4 Batch   90/538 - Train Accuracy: 0.9299, Validation Accuracy: 0.9368, Loss: 0.0680
# Epoch   4 Batch  100/538 - Train Accuracy: 0.9457, Validation Accuracy: 0.9377, Loss: 0.0545
# Epoch   4 Batch  110/538 - Train Accuracy: 0.9369, Validation Accuracy: 0.9450, Loss: 0.0529
# Epoch   4 Batch  120/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9421, Loss: 0.0471
# Epoch   4 Batch  130/538 - Train Accuracy: 0.9513, Validation Accuracy: 0.9363, Loss: 0.0504
# Epoch   4 Batch  140/538 - Train Accuracy: 0.9277, Validation Accuracy: 0.9375, Loss: 0.0694
# Epoch   4 Batch  150/538 - Train Accuracy: 0.9475, Validation Accuracy: 0.9364, Loss: 0.0489
# Epoch   4 Batch  160/538 - Train Accuracy: 0.9239, Validation Accuracy: 0.9324, Loss: 0.0538
# Epoch   4 Batch  170/538 - Train Accuracy: 0.9232, Validation Accuracy: 0.9343, Loss: 0.0588
# Epoch   4 Batch  180/538 - Train Accuracy: 0.9362, Validation Accuracy: 0.9409, Loss: 0.0549
# Epoch   4 Batch  190/538 - Train Accuracy: 0.9323, Validation Accuracy: 0.9442, Loss: 0.0690
# Epoch   4 Batch  200/538 - Train Accuracy: 0.9244, Validation Accuracy: 0.9354, Loss: 0.0478
# Epoch   4 Batch  210/538 - Train Accuracy: 0.9278, Validation Accuracy: 0.9348, Loss: 0.0561
# Epoch   4 Batch  220/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9386, Loss: 0.0569
# Epoch   4 Batch  230/538 - Train Accuracy: 0.9227, Validation Accuracy: 0.9391, Loss: 0.0538
# Epoch   4 Batch  240/538 - Train Accuracy: 0.9348, Validation Accuracy: 0.9370, Loss: 0.0551
# Epoch   4 Batch  250/538 - Train Accuracy: 0.9473, Validation Accuracy: 0.9442, Loss: 0.0478
# Epoch   4 Batch  260/538 - Train Accuracy: 0.9059, Validation Accuracy: 0.9341, Loss: 0.0602
# Epoch   4 Batch  270/538 - Train Accuracy: 0.9523, Validation Accuracy: 0.9380, Loss: 0.0477
# Epoch   4 Batch  280/538 - Train Accuracy: 0.9507, Validation Accuracy: 0.9419, Loss: 0.0423
# Epoch   4 Batch  290/538 - Train Accuracy: 0.9555, Validation Accuracy: 0.9430, Loss: 0.0463
# Epoch   4 Batch  300/538 - Train Accuracy: 0.9403, Validation Accuracy: 0.9476, Loss: 0.0528
# Epoch   4 Batch  310/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9473, Loss: 0.0524
# Epoch   4 Batch  320/538 - Train Accuracy: 0.9375, Validation Accuracy: 0.9554, Loss: 0.0431
# Epoch   4 Batch  330/538 - Train Accuracy: 0.9542, Validation Accuracy: 0.9352, Loss: 0.0452
# Epoch   4 Batch  340/538 - Train Accuracy: 0.9377, Validation Accuracy: 0.9458, Loss: 0.0484
# Epoch   4 Batch  350/538 - Train Accuracy: 0.9407, Validation Accuracy: 0.9379, Loss: 0.0543
# Epoch   4 Batch  360/538 - Train Accuracy: 0.9432, Validation Accuracy: 0.9442, Loss: 0.0450
# Epoch   4 Batch  370/538 - Train Accuracy: 0.9537, Validation Accuracy: 0.9496, Loss: 0.0484
# Epoch   4 Batch  380/538 - Train Accuracy: 0.9449, Validation Accuracy: 0.9522, Loss: 0.0423
# Epoch   4 Batch  390/538 - Train Accuracy: 0.9524, Validation Accuracy: 0.9513, Loss: 0.0411
# Epoch   4 Batch  400/538 - Train Accuracy: 0.9496, Validation Accuracy: 0.9441, Loss: 0.0488
# Epoch   4 Batch  410/538 - Train Accuracy: 0.9508, Validation Accuracy: 0.9359, Loss: 0.0489
# Epoch   4 Batch  420/538 - Train Accuracy: 0.9418, Validation Accuracy: 0.9457, Loss: 0.0459
# Epoch   4 Batch  430/538 - Train Accuracy: 0.9346, Validation Accuracy: 0.9430, Loss: 0.0440
# Epoch   4 Batch  440/538 - Train Accuracy: 0.9473, Validation Accuracy: 0.9428, Loss: 0.0484
# Epoch   4 Batch  450/538 - Train Accuracy: 0.9182, Validation Accuracy: 0.9485, Loss: 0.0592
# Epoch   4 Batch  460/538 - Train Accuracy: 0.9334, Validation Accuracy: 0.9522, Loss: 0.0483
# Epoch   4 Batch  470/538 - Train Accuracy: 0.9522, Validation Accuracy: 0.9542, Loss: 0.0427
# Epoch   4 Batch  480/538 - Train Accuracy: 0.9561, Validation Accuracy: 0.9551, Loss: 0.0437
# Epoch   4 Batch  490/538 - Train Accuracy: 0.9500, Validation Accuracy: 0.9538, Loss: 0.0426
# Epoch   4 Batch  500/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9505, Loss: 0.0319
# Epoch   4 Batch  510/538 - Train Accuracy: 0.9598, Validation Accuracy: 0.9467, Loss: 0.0406
# Epoch   4 Batch  520/538 - Train Accuracy: 0.9377, Validation Accuracy: 0.9508, Loss: 0.0438
# Epoch   4 Batch  530/538 - Train Accuracy: 0.9252, Validation Accuracy: 0.9517, Loss: 0.0499
# Epoch   5 Batch   10/538 - Train Accuracy: 0.9389, Validation Accuracy: 0.9339, Loss: 0.0483
# Epoch   5 Batch   20/538 - Train Accuracy: 0.9552, Validation Accuracy: 0.9553, Loss: 0.0454
# Epoch   5 Batch   30/538 - Train Accuracy: 0.9369, Validation Accuracy: 0.9403, Loss: 0.0512
# Epoch   5 Batch   40/538 - Train Accuracy: 0.9485, Validation Accuracy: 0.9615, Loss: 0.0347
# Epoch   5 Batch   50/538 - Train Accuracy: 0.9490, Validation Accuracy: 0.9499, Loss: 0.0384
# Epoch   5 Batch   60/538 - Train Accuracy: 0.9373, Validation Accuracy: 0.9416, Loss: 0.0450
# Epoch   5 Batch   70/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9464, Loss: 0.0374
# Epoch   5 Batch   80/538 - Train Accuracy: 0.9516, Validation Accuracy: 0.9480, Loss: 0.0437
# Epoch   5 Batch   90/538 - Train Accuracy: 0.9485, Validation Accuracy: 0.9572, Loss: 0.0460
# Epoch   5 Batch  100/538 - Train Accuracy: 0.9660, Validation Accuracy: 0.9526, Loss: 0.0376
# Epoch   5 Batch  110/538 - Train Accuracy: 0.9482, Validation Accuracy: 0.9599, Loss: 0.0345
# Epoch   5 Batch  120/538 - Train Accuracy: 0.9600, Validation Accuracy: 0.9542, Loss: 0.0313
# Epoch   5 Batch  130/538 - Train Accuracy: 0.9528, Validation Accuracy: 0.9519, Loss: 0.0361
# Epoch   5 Batch  140/538 - Train Accuracy: 0.9346, Validation Accuracy: 0.9547, Loss: 0.0525
# Epoch   5 Batch  150/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9570, Loss: 0.0347
# Epoch   5 Batch  160/538 - Train Accuracy: 0.9416, Validation Accuracy: 0.9455, Loss: 0.0369
# Epoch   5 Batch  170/538 - Train Accuracy: 0.9425, Validation Accuracy: 0.9469, Loss: 0.0428
# Epoch   5 Batch  180/538 - Train Accuracy: 0.9422, Validation Accuracy: 0.9585, Loss: 0.0402
# Epoch   5 Batch  190/538 - Train Accuracy: 0.9468, Validation Accuracy: 0.9537, Loss: 0.0496
# Epoch   5 Batch  200/538 - Train Accuracy: 0.9588, Validation Accuracy: 0.9515, Loss: 0.0314
# Epoch   5 Batch  210/538 - Train Accuracy: 0.9483, Validation Accuracy: 0.9533, Loss: 0.0399
# Epoch   5 Batch  220/538 - Train Accuracy: 0.9448, Validation Accuracy: 0.9469, Loss: 0.0418
# Epoch   5 Batch  230/538 - Train Accuracy: 0.9439, Validation Accuracy: 0.9600, Loss: 0.0365
# Epoch   5 Batch  240/538 - Train Accuracy: 0.9414, Validation Accuracy: 0.9526, Loss: 0.0406
# Epoch   5 Batch  250/538 - Train Accuracy: 0.9549, Validation Accuracy: 0.9577, Loss: 0.0369
# Epoch   5 Batch  260/538 - Train Accuracy: 0.9249, Validation Accuracy: 0.9411, Loss: 0.0429
# Epoch   5 Batch  270/538 - Train Accuracy: 0.9605, Validation Accuracy: 0.9416, Loss: 0.0333
# Epoch   5 Batch  280/538 - Train Accuracy: 0.9513, Validation Accuracy: 0.9505, Loss: 0.0320
# Epoch   5 Batch  290/538 - Train Accuracy: 0.9566, Validation Accuracy: 0.9558, Loss: 0.0310
# Epoch   5 Batch  300/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9606, Loss: 0.0383
# Epoch   5 Batch  310/538 - Train Accuracy: 0.9703, Validation Accuracy: 0.9521, Loss: 0.0408
# Epoch   5 Batch  320/538 - Train Accuracy: 0.9552, Validation Accuracy: 0.9586, Loss: 0.0319
# Epoch   5 Batch  330/538 - Train Accuracy: 0.9706, Validation Accuracy: 0.9586, Loss: 0.0324
# Epoch   5 Batch  340/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9531, Loss: 0.0352
# Epoch   5 Batch  350/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9554, Loss: 0.0403
# Epoch   5 Batch  360/538 - Train Accuracy: 0.9475, Validation Accuracy: 0.9616, Loss: 0.0339
# Epoch   5 Batch  370/538 - Train Accuracy: 0.9635, Validation Accuracy: 0.9521, Loss: 0.0344
# Epoch   5 Batch  380/538 - Train Accuracy: 0.9533, Validation Accuracy: 0.9602, Loss: 0.0319
# Epoch   5 Batch  390/538 - Train Accuracy: 0.9524, Validation Accuracy: 0.9545, Loss: 0.0305
# Epoch   5 Batch  400/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9560, Loss: 0.0334
# Epoch   5 Batch  410/538 - Train Accuracy: 0.9660, Validation Accuracy: 0.9535, Loss: 0.0335
# Epoch   5 Batch  420/538 - Train Accuracy: 0.9641, Validation Accuracy: 0.9554, Loss: 0.0356
# Epoch   5 Batch  430/538 - Train Accuracy: 0.9383, Validation Accuracy: 0.9506, Loss: 0.0327
# Epoch   5 Batch  440/538 - Train Accuracy: 0.9598, Validation Accuracy: 0.9588, Loss: 0.0333
# Epoch   5 Batch  450/538 - Train Accuracy: 0.9386, Validation Accuracy: 0.9634, Loss: 0.0464
# Epoch   5 Batch  460/538 - Train Accuracy: 0.9408, Validation Accuracy: 0.9590, Loss: 0.0360
# Epoch   5 Batch  470/538 - Train Accuracy: 0.9585, Validation Accuracy: 0.9593, Loss: 0.0335
# Epoch   5 Batch  480/538 - Train Accuracy: 0.9648, Validation Accuracy: 0.9686, Loss: 0.0322
# Epoch   5 Batch  490/538 - Train Accuracy: 0.9423, Validation Accuracy: 0.9545, Loss: 0.0323
# Epoch   5 Batch  500/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9609, Loss: 0.0247
# Epoch   5 Batch  510/538 - Train Accuracy: 0.9587, Validation Accuracy: 0.9457, Loss: 0.0297
# Epoch   5 Batch  520/538 - Train Accuracy: 0.9584, Validation Accuracy: 0.9643, Loss: 0.0332
# Epoch   5 Batch  530/538 - Train Accuracy: 0.9469, Validation Accuracy: 0.9657, Loss: 0.0382
# Epoch   6 Batch   10/538 - Train Accuracy: 0.9523, Validation Accuracy: 0.9542, Loss: 0.0367
# Epoch   6 Batch   20/538 - Train Accuracy: 0.9663, Validation Accuracy: 0.9561, Loss: 0.0332
# Epoch   6 Batch   30/538 - Train Accuracy: 0.9520, Validation Accuracy: 0.9560, Loss: 0.0391
# Epoch   6 Batch   40/538 - Train Accuracy: 0.9670, Validation Accuracy: 0.9670, Loss: 0.0249
# Epoch   6 Batch   50/538 - Train Accuracy: 0.9611, Validation Accuracy: 0.9505, Loss: 0.0305
# Epoch   6 Batch   60/538 - Train Accuracy: 0.9564, Validation Accuracy: 0.9469, Loss: 0.0339
# Epoch   6 Batch   70/538 - Train Accuracy: 0.9715, Validation Accuracy: 0.9554, Loss: 0.0272
# Epoch   6 Batch   80/538 - Train Accuracy: 0.9598, Validation Accuracy: 0.9673, Loss: 0.0314
# Epoch   6 Batch   90/538 - Train Accuracy: 0.9587, Validation Accuracy: 0.9593, Loss: 0.0362
# Epoch   6 Batch  100/538 - Train Accuracy: 0.9580, Validation Accuracy: 0.9620, Loss: 0.0273
# Epoch   6 Batch  110/538 - Train Accuracy: 0.9600, Validation Accuracy: 0.9611, Loss: 0.0286
# Epoch   6 Batch  120/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9677, Loss: 0.0220
# Epoch   6 Batch  130/538 - Train Accuracy: 0.9608, Validation Accuracy: 0.9609, Loss: 0.0280
# Epoch   6 Batch  140/538 - Train Accuracy: 0.9471, Validation Accuracy: 0.9590, Loss: 0.0403
# Epoch   6 Batch  150/538 - Train Accuracy: 0.9666, Validation Accuracy: 0.9632, Loss: 0.0259
# Epoch   6 Batch  160/538 - Train Accuracy: 0.9548, Validation Accuracy: 0.9640, Loss: 0.0274
# Epoch   6 Batch  170/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9586, Loss: 0.0346
# Epoch   6 Batch  180/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9645, Loss: 0.0305
# Epoch   6 Batch  190/538 - Train Accuracy: 0.9533, Validation Accuracy: 0.9576, Loss: 0.0413
# Epoch   6 Batch  200/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9656, Loss: 0.0229
# Epoch   6 Batch  210/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9563, Loss: 0.0322
# Epoch   6 Batch  220/538 - Train Accuracy: 0.9481, Validation Accuracy: 0.9485, Loss: 0.0325
# Epoch   6 Batch  230/538 - Train Accuracy: 0.9574, Validation Accuracy: 0.9613, Loss: 0.0287
# Epoch   6 Batch  240/538 - Train Accuracy: 0.9543, Validation Accuracy: 0.9716, Loss: 0.0296
# Epoch   6 Batch  250/538 - Train Accuracy: 0.9672, Validation Accuracy: 0.9638, Loss: 0.0263
# Epoch   6 Batch  260/538 - Train Accuracy: 0.9442, Validation Accuracy: 0.9588, Loss: 0.0336
# Epoch   6 Batch  270/538 - Train Accuracy: 0.9652, Validation Accuracy: 0.9553, Loss: 0.0258
# Epoch   6 Batch  280/538 - Train Accuracy: 0.9682, Validation Accuracy: 0.9560, Loss: 0.0225
# Epoch   6 Batch  290/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9574, Loss: 0.0244
# Epoch   6 Batch  300/538 - Train Accuracy: 0.9665, Validation Accuracy: 0.9672, Loss: 0.0291
# Epoch   6 Batch  310/538 - Train Accuracy: 0.9760, Validation Accuracy: 0.9611, Loss: 0.0328
# Epoch   6 Batch  320/538 - Train Accuracy: 0.9669, Validation Accuracy: 0.9647, Loss: 0.0258
# Epoch   6 Batch  330/538 - Train Accuracy: 0.9701, Validation Accuracy: 0.9634, Loss: 0.0254
# Epoch   6 Batch  340/538 - Train Accuracy: 0.9566, Validation Accuracy: 0.9629, Loss: 0.0253
# Epoch   6 Batch  350/538 - Train Accuracy: 0.9501, Validation Accuracy: 0.9613, Loss: 0.0328
# Epoch   6 Batch  360/538 - Train Accuracy: 0.9541, Validation Accuracy: 0.9668, Loss: 0.0259
# Epoch   6 Batch  370/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9627, Loss: 0.0277
# Epoch   6 Batch  380/538 - Train Accuracy: 0.9713, Validation Accuracy: 0.9618, Loss: 0.0240
# Epoch   6 Batch  390/538 - Train Accuracy: 0.9654, Validation Accuracy: 0.9583, Loss: 0.0228
# Epoch   6 Batch  400/538 - Train Accuracy: 0.9771, Validation Accuracy: 0.9533, Loss: 0.0262
# Epoch   6 Batch  410/538 - Train Accuracy: 0.9746, Validation Accuracy: 0.9643, Loss: 0.0270
# Epoch   6 Batch  420/538 - Train Accuracy: 0.9553, Validation Accuracy: 0.9595, Loss: 0.0284
# Epoch   6 Batch  430/538 - Train Accuracy: 0.9404, Validation Accuracy: 0.9661, Loss: 0.0289
# Epoch   6 Batch  440/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9663, Loss: 0.0250
# Epoch   6 Batch  450/538 - Train Accuracy: 0.9384, Validation Accuracy: 0.9679, Loss: 0.0364
# Epoch   6 Batch  460/538 - Train Accuracy: 0.9600, Validation Accuracy: 0.9657, Loss: 0.0279
# Epoch   6 Batch  470/538 - Train Accuracy: 0.9695, Validation Accuracy: 0.9723, Loss: 0.0261
# Epoch   6 Batch  480/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9707, Loss: 0.0250
# Epoch   6 Batch  490/538 - Train Accuracy: 0.9578, Validation Accuracy: 0.9695, Loss: 0.0244
# Epoch   6 Batch  500/538 - Train Accuracy: 0.9769, Validation Accuracy: 0.9711, Loss: 0.0185
# Epoch   6 Batch  510/538 - Train Accuracy: 0.9751, Validation Accuracy: 0.9599, Loss: 0.0232
# Epoch   6 Batch  520/538 - Train Accuracy: 0.9613, Validation Accuracy: 0.9640, Loss: 0.0262
# Epoch   6 Batch  530/538 - Train Accuracy: 0.9529, Validation Accuracy: 0.9675, Loss: 0.0283
# Epoch   7 Batch   10/538 - Train Accuracy: 0.9594, Validation Accuracy: 0.9643, Loss: 0.0282
# Epoch   7 Batch   20/538 - Train Accuracy: 0.9760, Validation Accuracy: 0.9640, Loss: 0.0261
# Epoch   7 Batch   30/538 - Train Accuracy: 0.9633, Validation Accuracy: 0.9538, Loss: 0.0299
# Epoch   7 Batch   40/538 - Train Accuracy: 0.9688, Validation Accuracy: 0.9711, Loss: 0.0202
# Epoch   7 Batch   50/538 - Train Accuracy: 0.9623, Validation Accuracy: 0.9640, Loss: 0.0238
# Epoch   7 Batch   60/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9645, Loss: 0.0279
# Epoch   7 Batch   70/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9666, Loss: 0.0197
# Epoch   7 Batch   80/538 - Train Accuracy: 0.9791, Validation Accuracy: 0.9698, Loss: 0.0239
# Epoch   7 Batch   90/538 - Train Accuracy: 0.9606, Validation Accuracy: 0.9627, Loss: 0.0292
# Epoch   7 Batch  100/538 - Train Accuracy: 0.9729, Validation Accuracy: 0.9579, Loss: 0.0216
# Epoch   7 Batch  110/538 - Train Accuracy: 0.9736, Validation Accuracy: 0.9695, Loss: 0.0218
# Epoch   7 Batch  120/538 - Train Accuracy: 0.9717, Validation Accuracy: 0.9711, Loss: 0.0182
# Epoch   7 Batch  130/538 - Train Accuracy: 0.9624, Validation Accuracy: 0.9606, Loss: 0.0243
# Epoch   7 Batch  140/538 - Train Accuracy: 0.9547, Validation Accuracy: 0.9682, Loss: 0.0314
# Epoch   7 Batch  150/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9631, Loss: 0.0206
# Epoch   7 Batch  160/538 - Train Accuracy: 0.9730, Validation Accuracy: 0.9670, Loss: 0.0229
# Epoch   7 Batch  170/538 - Train Accuracy: 0.9673, Validation Accuracy: 0.9709, Loss: 0.0271
# Epoch   7 Batch  180/538 - Train Accuracy: 0.9619, Validation Accuracy: 0.9705, Loss: 0.0263
# Epoch   7 Batch  190/538 - Train Accuracy: 0.9645, Validation Accuracy: 0.9656, Loss: 0.0338
# Epoch   7 Batch  200/538 - Train Accuracy: 0.9695, Validation Accuracy: 0.9615, Loss: 0.0186
# Epoch   7 Batch  210/538 - Train Accuracy: 0.9667, Validation Accuracy: 0.9600, Loss: 0.0252
# Epoch   7 Batch  220/538 - Train Accuracy: 0.9455, Validation Accuracy: 0.9570, Loss: 0.0274
# Epoch   7 Batch  230/538 - Train Accuracy: 0.9533, Validation Accuracy: 0.9627, Loss: 0.0236
# Epoch   7 Batch  240/538 - Train Accuracy: 0.9633, Validation Accuracy: 0.9680, Loss: 0.0234
# Epoch   7 Batch  250/538 - Train Accuracy: 0.9766, Validation Accuracy: 0.9670, Loss: 0.0204
# Epoch   7 Batch  260/538 - Train Accuracy: 0.9468, Validation Accuracy: 0.9673, Loss: 0.0259
# Epoch   7 Batch  270/538 - Train Accuracy: 0.9621, Validation Accuracy: 0.9696, Loss: 0.0213
# Epoch   7 Batch  280/538 - Train Accuracy: 0.9753, Validation Accuracy: 0.9670, Loss: 0.0183
# Epoch   7 Batch  290/538 - Train Accuracy: 0.9723, Validation Accuracy: 0.9689, Loss: 0.0186
# Epoch   7 Batch  300/538 - Train Accuracy: 0.9725, Validation Accuracy: 0.9728, Loss: 0.0238
# Epoch   7 Batch  310/538 - Train Accuracy: 0.9732, Validation Accuracy: 0.9657, Loss: 0.0278
# Epoch   7 Batch  320/538 - Train Accuracy: 0.9738, Validation Accuracy: 0.9689, Loss: 0.0190
# Epoch   7 Batch  330/538 - Train Accuracy: 0.9775, Validation Accuracy: 0.9638, Loss: 0.0210
# Epoch   7 Batch  340/538 - Train Accuracy: 0.9686, Validation Accuracy: 0.9700, Loss: 0.0201
# Epoch   7 Batch  350/538 - Train Accuracy: 0.9661, Validation Accuracy: 0.9679, Loss: 0.0272
# Epoch   7 Batch  360/538 - Train Accuracy: 0.9594, Validation Accuracy: 0.9657, Loss: 0.0211
# Epoch   7 Batch  370/538 - Train Accuracy: 0.9658, Validation Accuracy: 0.9679, Loss: 0.0230
# Epoch   7 Batch  380/538 - Train Accuracy: 0.9684, Validation Accuracy: 0.9730, Loss: 0.0221
# Epoch   7 Batch  390/538 - Train Accuracy: 0.9663, Validation Accuracy: 0.9620, Loss: 0.0200
# Epoch   7 Batch  400/538 - Train Accuracy: 0.9719, Validation Accuracy: 0.9570, Loss: 0.0205
# Epoch   7 Batch  410/538 - Train Accuracy: 0.9789, Validation Accuracy: 0.9693, Loss: 0.0196
# Epoch   7 Batch  420/538 - Train Accuracy: 0.9631, Validation Accuracy: 0.9634, Loss: 0.0247
# Epoch   7 Batch  430/538 - Train Accuracy: 0.9570, Validation Accuracy: 0.9542, Loss: 0.0221
# Epoch   7 Batch  440/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9650, Loss: 0.0220
# Epoch   7 Batch  450/538 - Train Accuracy: 0.9438, Validation Accuracy: 0.9709, Loss: 0.0319
# Epoch   7 Batch  460/538 - Train Accuracy: 0.9697, Validation Accuracy: 0.9762, Loss: 0.0212
# Epoch   7 Batch  470/538 - Train Accuracy: 0.9730, Validation Accuracy: 0.9757, Loss: 0.0212
# Epoch   7 Batch  480/538 - Train Accuracy: 0.9823, Validation Accuracy: 0.9670, Loss: 0.0207
# Epoch   7 Batch  490/538 - Train Accuracy: 0.9650, Validation Accuracy: 0.9711, Loss: 0.0196
# Epoch   7 Batch  500/538 - Train Accuracy: 0.9815, Validation Accuracy: 0.9755, Loss: 0.0148
# Epoch   7 Batch  510/538 - Train Accuracy: 0.9721, Validation Accuracy: 0.9757, Loss: 0.0193
# Epoch   7 Batch  520/538 - Train Accuracy: 0.9750, Validation Accuracy: 0.9734, Loss: 0.0225
# Epoch   7 Batch  530/538 - Train Accuracy: 0.9559, Validation Accuracy: 0.9734, Loss: 0.0243
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    sentence_ids = []
    for word in sentence.lower().split(' '):
        id = vocab_to_int.get(word, vocab_to_int['<UNK>'])
        sentence_ids.append(id)    
    return sentence_ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [67, 148, 183, 71, 121, 215, 187]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [305, 264, 247, 162, 224, 130, 44, 343, 1]
#   French Words: il a vu un vieux camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
